# %%
import pandas as pd

# %%
xls = pd.read_excel('T01.xlsx')

# %%
all1 = pd.DataFrame([])

# %%
for sh in xls.sheet_names:
    df = pd.read_excel('T01.xlsx', sheet_name = sh)
    df["month"] = sh
    all1.append(df)
print(all1)
# Out:
#    id  balance   gender    month
# 0   1      1020    male  01 2019
# 1   2      1030  female  01 2019
# 2   3      1125  female  01 2019
# 3   4      1345    male  01 2019
# 4   5      1223    male  01 2019
# 5   6      1223    male  01 2019
# 6   7      1442  female  01 2019
# 7   8      1334    male  01 2019
# 8   9      1244  female  01 2019
# 9  10      1664    male  01 2019
#    id  balance   gender    month
# 0   1      1020    male  02 2019
# 1   2      1030  female  02 2019
# 2   3      1125  female  02 2019
# 3   4      1345    male  02 2019
# 4   5      1223    male  02 2019
# 5   6      1223    male  02 2019
# 6   7      1442  female  02 2019
# 7   8      1334    male  02 2019
# 8   9      1244  female  02 2019
# 9  10      1664    male  02 2019
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_excel('T01.xlsx', sheet_name = sh)
# Out:
#    id  balance   gender
# 0   1      1020    male
# 1   2      1030  female
# 2   3      1125  female
# 3   4      1345    male
# 4   5      1223    male
# 5   6      1223    male
# 6   7      1442  female
# 7   8      1334    male
# 8   9      1244  female
# 9  10      1664    male

# %%
list_of_df=[]
for i in range(len(sheet_names)):
    df = pd.read_excel('T01.xlsx', sheet_name = i)
    list_of_df.append(df)

# %%
df
# Out:
#    id  balance   gender
# 0   1      1020    male
# 1   2      1030  female
# 2   3      1125  female
# 3   4      1345    male
# 4   5      1223    male
# 5   6      1223    male
# 6   7      1442  female
# 7   8      1334    male
# 8   9      1244  female
# 9  10      1664    male

# %%
df
# Out:
#    id  balance   gender     name
# 0   1      1020    male  02 2019
# 1   2      1030  female  02 2019
# 2   3      1125  female  02 2019
# 3   4      1345    male  02 2019
# 4   5      1223    male  02 2019
# 5   6      1223    male  02 2019
# 6   7      1442  female  02 2019
# 7   8      1334    male  02 2019
# 8   9      1244  female  02 2019
# 9  10      1664    male  02 2019

# %%
import numpy as np
all01 =np.array(all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ea9916474bff> in <module>
#       1 import numpy as np
# ----> 2 all01 =np.array(all)
#
# ValueError: cannot copy sequence with size 10 to array axis with dimension 4
